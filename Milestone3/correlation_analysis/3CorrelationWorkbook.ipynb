# %% [markdown]
# # Correlation Workbook

# %% [markdown]
# This notebook is used as an intermediate step to a cool correlation network visualization. The output of this notebook is the input of the notebook that makes that visualization.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../../carpentry/completeDF.csv')

# %%
df = df.drop(['CountryName', 'Year', 'Continent', 'Region1', 'ISO3'], axis=1)

df.head()
# Out:
#    SPRURTOTLZS  SPPOPAG23MAIN  SPPOPAG24FEIN  SPPOPAG24MAIN  SPPOPAG25FEIN  \
# 0       63.572        30842.0        29782.0        30902.0        29833.0
# 1       63.300        29040.0        28732.0        28987.0        28894.0
# 2       62.751        27308.0        27663.0        26899.0        27689.0
# 3       62.201        25873.0        26855.0        25133.0        26544.0
# 4       61.646        24704.0        26327.0        23908.0        25748.0
#
#    SPPOPAG25MAIN  SPPOPDPND  SPPOPDPNDOL  SPPOPDPNDYG  SPPOPTOTL  ...  \
# 0        30896.0  61.994909     8.901594    53.093316  3286542.0  ...
# 1        29109.0  62.715405     9.191396    53.524009  3266790.0  ...
# 2        26863.0  63.311979     9.516996    53.794984  3247039.0  ...
# 3        24681.0  63.743013     9.867033    53.875979  3227287.0  ...
# 4        23079.0  64.077234    10.223010    53.854224  3207536.0  ...
#
#    NVSRVEMPLKD  TXVALINSFZSWT  BXGSRINSFZS  NYGNSICTRGNZS   NYGNSICTRCN  \
# ...

# %%
df_corr = df.corr()

# %%
df_corr.head()
# Out:
#                SPRURTOTLZS  SPPOPAG23MAIN  SPPOPAG24FEIN  SPPOPAG24MAIN  \
# SPRURTOTLZS       1.000000       0.105300       0.103293       0.102547
# SPPOPAG23MAIN     0.105300       1.000000       0.998824       0.999228
# SPPOPAG24FEIN     0.103293       0.998824       1.000000       0.999581
# SPPOPAG24MAIN     0.102547       0.999228       0.999581       1.000000
# SPPOPAG25FEIN     0.100269       0.996621       0.999130       0.998830
#
#                SPPOPAG25FEIN  SPPOPAG25MAIN  SPPOPDPND  SPPOPDPNDOL  \
# SPRURTOTLZS         0.100269       0.099773   0.652756    -0.618212
# SPPOPAG23MAIN       0.996621       0.997050  -0.106439    -0.069490
# SPPOPAG24FEIN       0.999130       0.998685  -0.108902    -0.068972
# SPPOPAG24MAIN       0.998830       0.999206  -0.109281    -0.066415
# SPPOPAG25FEIN       1.000000       0.999593  -0.111901    -0.065663
#
#                SPPOPDPNDYG  SPPOPTOTL  ...  NVSRVEMPLKD  TXVALINSFZSWT  \
# ...

# %%
df_corr_abs = df_corr.abs()

df_corr_abs.head()
# Out:
#                SPRURTOTLZS  SPPOPAG23MAIN  SPPOPAG24FEIN  SPPOPAG24MAIN  \
# SPRURTOTLZS       1.000000       0.105300       0.103293       0.102547
# SPPOPAG23MAIN     0.105300       1.000000       0.998824       0.999228
# SPPOPAG24FEIN     0.103293       0.998824       1.000000       0.999581
# SPPOPAG24MAIN     0.102547       0.999228       0.999581       1.000000
# SPPOPAG25FEIN     0.100269       0.996621       0.999130       0.998830
#
#                SPPOPAG25FEIN  SPPOPAG25MAIN  SPPOPDPND  SPPOPDPNDOL  \
# SPRURTOTLZS         0.100269       0.099773   0.652756     0.618212
# SPPOPAG23MAIN       0.996621       0.997050   0.106439     0.069490
# SPPOPAG24FEIN       0.999130       0.998685   0.108902     0.068972
# SPPOPAG24MAIN       0.998830       0.999206   0.109281     0.066415
# SPPOPAG25FEIN       1.000000       0.999593   0.111901     0.065663
#
#                SPPOPDPNDYG  SPPOPTOTL  ...  NVSRVEMPLKD  TXVALINSFZSWT  \
# ...

# %%
df_nodes = df_corr_abs.where(df_corr != 1, 0)
df_nodes = df_nodes.where(df_nodes <= 0.9, 1)
#df_nodes = df_nodes.where(df_nodes >= -.9, 1)
#df_nodes = df_nodes.where(df_nodes >= 0.9, 1)
df_nodes = df_nodes.where(df_nodes >= 1, 0)

# %%
df_nodes.head()
# Out:
#                SPRURTOTLZS  SPPOPAG23MAIN  SPPOPAG24FEIN  SPPOPAG24MAIN  \
# SPRURTOTLZS            0.0            0.0            0.0            0.0
# SPPOPAG23MAIN          0.0            0.0            1.0            1.0
# SPPOPAG24FEIN          0.0            1.0            0.0            1.0
# SPPOPAG24MAIN          0.0            1.0            1.0            0.0
# SPPOPAG25FEIN          0.0            1.0            1.0            1.0
#
#                SPPOPAG25FEIN  SPPOPAG25MAIN  SPPOPDPND  SPPOPDPNDOL  \
# SPRURTOTLZS              0.0            0.0        0.0          0.0
# SPPOPAG23MAIN            1.0            1.0        0.0          0.0
# SPPOPAG24FEIN            1.0            1.0        0.0          0.0
# SPPOPAG24MAIN            1.0            1.0        0.0          0.0
# SPPOPAG25FEIN            0.0            1.0        0.0          0.0
#
#                SPPOPDPNDYG  SPPOPTOTL  ...  NVSRVEMPLKD  TXVALINSFZSWT  \
# ...

# %%
df_nodes_int = df_nodes.astype(int)

df_nodes_int.head()
# Out:
#                SPRURTOTLZS  SPPOPAG23MAIN  SPPOPAG24FEIN  SPPOPAG24MAIN  \
# SPRURTOTLZS              0              0              0              0
# SPPOPAG23MAIN            0              0              1              1
# SPPOPAG24FEIN            0              1              0              1
# SPPOPAG24MAIN            0              1              1              0
# SPPOPAG25FEIN            0              1              1              1
#
#                SPPOPAG25FEIN  SPPOPAG25MAIN  SPPOPDPND  SPPOPDPNDOL  \
# SPRURTOTLZS                0              0          0            0
# SPPOPAG23MAIN              1              1          0            0
# SPPOPAG24FEIN              1              1          0            0
# SPPOPAG24MAIN              1              1          0            0
# SPPOPAG25FEIN              0              1          0            0
#
#                SPPOPDPNDYG  SPPOPTOTL  ...  NVSRVEMPLKD  TXVALINSFZSWT  \
# ...

# %%
df_nodes_int.to_csv('df_nodes.csv')

# %%
# What is the ratio of correlations that were above or below the 0.9 threshold

df_nodes.apply(pd.value_counts).T.sum()
# Out:
# 0.0    327008.0
# 1.0     11716.0
# dtype: float64

# %%
11716 / (327008 + 11716)
# Out:
# 0.03458863263305818

# %%
6000 / (176000+6000)
# Out:
# 0.03296703296703297

# %%
327008 + 11716
# Out:
# 338724

# %%
x = 0

for index, row in df_nodes.iteritems():
    print(f"{index} + {row}")
        
print(x)
# Out:
# SPRURTOTLZS + SPRURTOTLZS        0.0
# SPPOPAG23MAIN      0.0
# SPPOPAG24FEIN      0.0
# SPPOPAG24MAIN      0.0
# SPPOPAG25FEIN      0.0
#                   ...
# NYGNSICTRCD        0.0
# BNKLTPTXLCD        0.0
# NYGNSICTRZS        0.0
# NEDABDEFLZS        0.0
# NECONPRVTPCKDZG    0.0
# Name: SPRURTOTLZS, Length: 582, dtype: float64
# SPPOPAG23MAIN + SPRURTOTLZS        0.0
# SPPOPAG23MAIN      0.0
# SPPOPAG24FEIN      1.0
# SPPOPAG24MAIN      1.0
# SPPOPAG25FEIN      1.0
#                   ...
# NYGNSICTRCD        0.0
# BNKLTPTXLCD        0.0
# NYGNSICTRZS        0.0
# NEDABDEFLZS        0.0
# NECONPRVTPCKDZG    0.0
# Name: SPPOPAG23MAIN, Length: 582, dtype: float64
# SPPOPAG24FEIN + SPRURTOTLZS        0.0
# SPPOPAG23MAIN      1.0
# SPPOPAG24FEIN      0.0
# SPPOPAG24MAIN      1.0
# SPPOPAG25FEIN      1.0
#                   ...
# NYGNSICTRCD        0.0
# BNKLTPTXLCD        0.0
# NYGNSICTRZS        0.0
# NEDABDEFLZS        0.0
# NECONPRVTPCKDZG    0.0
# ...
